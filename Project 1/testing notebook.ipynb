# %% [markdown]
# # Rainfall n stuff in Southeast China
# (mainly in the Fujian / Anhui regions)

# %%
import logging
logging.basicConfig(level='INFO')

from ecmwf.datastores import Client
client = Client()
client.check_authentication()
# Out:
# {'id': 311913,
#  'sub': '6ac43757-66e1-4ae6-99ad-965c71abe9fa',
#  'role': None,
#  'email': 'linmichael706@gmail.com'}

# %%
jobs = client.get_jobs(sortby="-created", status="successful")
request_ids = []
while jobs is not None:  # Loop over pages
    request_ids.extend(jobs.request_ids)
    jobs = jobs.next  # Move to the next page

# %%
rqid = request_ids[0]

remote = client.get_remote(rqid)
# Out:
# INFO:ecmwf.datastores.processing:Request ID is 3a3e62ee-a35b-4b41-881b-799e13f1cfba

# %%
## extents

SE_CHINA_BBOX = [31.7, 115.0, 23.3, 123.2] ## covers fujian, zhejiang, southmost bit of anhui, bit of taiwan

# %%
import earthkit as ek
import earthkit.data as ekd
import earthkit.plots as ekp

request = {
        'product_type': 'monthly_averaged_reanalysis',
        'variable': 'total_precipitation',
        'year': '2025',
        'month': '12',
        'time': '00:00',
        'data_format': 'netcdf',
        'area': SE_CHINA_BBOX
}

data = ekd.from_source(
    'cds', 'reanalysis-era5-single-levels-monthly-means', request
)
# Out:
# 2026-02-03 10:02:40,842 INFO Request ID is 8d19d1aa-5828-41ff-afea-c34b458d2dcc
# 2026-02-03 10:02:42,807 INFO status has been updated to accepted
# 2026-02-03 10:02:56,659 INFO status has been updated to running
# 2026-02-03 10:03:04,316 INFO status has been updated to successful
# NetCDFFieldListReader(C:\Users\nookh\AppData\Local\Temp\tmp0n33itmm\cds-retriever-a12711ea326616ea05cc94ad74d3907c879305de33c15bdb6c115ed63f39883a.cache)

# %%
data
# Out:
# NetCDFFieldListReader(C:\Users\nookh\AppData\Local\Temp\tmp0n33itmm\cds-retriever-a12711ea326616ea05cc94ad74d3907c879305de33c15bdb6c115ed63f39883a.cache)

# %%
style = ekp.styles.Style(
    colors='Spectral_r',
    levels= range(232, 310, 2),
    units="kelvin",
    extend="both",
)

chart = ekp.Map(domain='China')

chart.grid_cells(data, style=style)

chart.coastlines(color="#555555")

chart.title("ERA5 monthly averaged {variable_name} - {time:%B %Y}")
chart.legend(label="{units}")
# Out:
# ---------------------------------------------------------------------------
# DimensionalityError                       Traceback (most recent call last)
# Cell In[6], line 9
#       1 style = ekp.styles.Style(
#       2     units="Pa",
#       3     extend="both",
#       4 )
#       7 chart = ekp.Map(domain='China')
# ----> 9 chart.grid_cells(data, style=style)
#      11 chart.coastlines(color="#555555")
#      13 chart.title("ERA5 monthly averaged {variable_name} - {time:%B %Y}")
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\earthkit\plots\components\subplots.py:404, in Subplot.plot_3D.<locals>.decorator.<locals>.wrapper(self, x, y, z, style, every, auto_style, *args, **kwargs)
#     392 @functools.wraps(method)
#     393 def wrapper(
#     394     self,
#    (...)    402     **kwargs,
#     403 ):
# --> 404     return self._extract_plottables(
#     405         method_name or method.__name__,
#     406         args=args,
#     407         x=x,
#     408         y=y,
#     409         z=z,
#     410         style=style,
#     411         every=every,
#     412         auto_style=auto_style,
#     413         extract_domain=extract_domain,
#     414         **kwargs,
#     415     )
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\earthkit\plots\components\subplots.py:570, in Subplot._extract_plottables(self, method_name, args, x, y, z, style, no_style, units, every, source_units, extract_domain, auto_style, regrid, metadata, **kwargs)
#     552 def _extract_plottables(
#     553     self,
#     554     method_name,
#    (...)    568     **kwargs,
#     569 ):
# --> 570     return extract_plottables_3D(
#     571         self,
#     572         method_name,
#     573         args,
#     574         x=x,
#     575         y=y,
#     576         z=z,
#     577         style=style,
#     578         no_style=no_style,
#     579         units=units,
#     580         every=every,
#     581         source_units=source_units,
#     582         extract_domain=extract_domain,
#     583         auto_style=auto_style,
#     584         regrid=regrid,
#     585         metadata=metadata,
#     586         **kwargs,
#     587     )
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\earthkit\plots\components\extractors.py:419, in extract_plottables_3D(subplot, method_name, args, x, y, z, style, no_style, units, xunits, yunits, every, source_units, extract_domain, auto_style, regrid, metadata, **kwargs)
#     416 style = configure_style(method_name, style, source, units, auto_style, kwargs)
#     418 # Step 4: Process z values (convert units, apply scale factors)
# --> 419 z_values = process_z_values(style, source, z)
#     421 # Step 5: Handle specialized grid types (healpix, octahedral)
#     422 mappable = _handle_specialized_grids(
#     423     subplot, source, z_values, style, method_name, kwargs
#     424 )
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\earthkit\plots\components\extractors.py:679, in process_z_values(style, source, z)
#     676     return None
#     678 # Convert units and apply scale factors
# --> 679 z_values = style.convert_units(source.z_values, source.units)
#     680 return style.apply_scale_factor(z_values)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\earthkit\plots\styles\__init__.py:266, in Style.convert_units(self, values, source_units, short_name)
#     261 if "anomaly" in short_name.lower() and metadata.units.anomaly_equivalence(
#     262     source_units
#     263 ):
#     264     return values
# --> 266 return metadata.units.convert(values, source_units, self._units)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\earthkit\plots\metadata\units.py:165, in convert(data, source_units, target_units)
#     162 target_units = _pintify(target_units)
#     164 try:
# --> 165     result = (data * source_units).to(target_units).magnitude
#     166 except ValueError as err:
#     167     for units in UNIT_EQUIVALENCE:
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\pint\facets\plain\quantity.py:536, in PlainQuantity.to(self, other, *contexts, **ctx_kwargs)
#     519 """Return PlainQuantity rescaled to different units.
#     520
#     521 Parameters
#    (...)    532 pint.PlainQuantity
#     533 """
#     534 other = to_units_container(other, self._REGISTRY)
# --> 536 magnitude = self._convert_magnitude_not_inplace(other, *contexts, **ctx_kwargs)
#     538 return self.__class__(magnitude, other)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\pint\facets\plain\quantity.py:480, in PlainQuantity._convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     477     with self._REGISTRY.context(*contexts, **ctx_kwargs):
#     478         return self._REGISTRY.convert(self._magnitude, self._units, other)
# --> 480 return self._REGISTRY.convert(self._magnitude, self._units, other)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\pint\facets\plain\registry.py:1050, in GenericPlainRegistry.convert(self, value, src, dst, inplace)
#    1047 if src == dst:
#    1048     return value
# -> 1050 return self._convert(value, src, dst, inplace)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\pint\facets\context\registry.py:405, in GenericContextRegistry._convert(self, value, src, dst, inplace)
#     401             src = self._active_ctx.transform(a, b, self, src)
#     403         value, src = src._magnitude, src._units
# --> 405 return super()._convert(value, src, dst, inplace)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\pint\facets\nonmultiplicative\registry.py:259, in GenericNonMultiplicativeRegistry._convert(self, value, src, dst, inplace)
#     257 # convert if no offset units are present
#     258 if not (src_offset_unit or dst_offset_unit):
# --> 259     return super()._convert(value, src, dst, inplace)
#     261 src_dim = self._get_dimensionality(src)
#     262 dst_dim = self._get_dimensionality(dst)
#
# File c:\Users\nookh\miniconda3\envs\ml_ff\Lib\site-packages\pint\facets\plain\registry.py:1085, in GenericPlainRegistry._convert(self, value, src, dst, inplace, check_dimensionality)
#    1082 factor = self._get_conversion_factor(src, dst)
#    1084 if isinstance(factor, DimensionalityError):
# -> 1085     raise factor
#    1087 # factor is type float and if our magnitude is type Decimal then
#    1088 # must first convert to Decimal before we can '*' the values
#    1089 if isinstance(value, Decimal):
#
# DimensionalityError: Cannot convert from 'meter' ([length]) to 'pascal' ([mass] / [length] / [time] ** 2)
